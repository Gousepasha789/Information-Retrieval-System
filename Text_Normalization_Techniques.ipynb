# %% [markdown]
# <a href="https://colab.research.google.com/github/Gousepasha789/Information-Retrieval-System/blob/main/Text_Normalization_Techniques.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
nltk.download('wordnet')
from nltk.corpus import wordnet
synonyms = []
antonyms = []
for syn in wordnet.synsets("Joy"):
  for l in syn.lemmas():
    synonyms.append(l.name())
    if l.antonyms():
      antonyms.append(l.antonyms()[0].name())
print('Synonyms are :')
print(set(synonyms))
print('Antonyms are:')
print(set(antonyms))
# Out:
# Synonyms are :
# {'joy', 'pleasure', 'joyousness', 'delight', 'rejoice', 'gladden', 'joyfulness'}
# Antonyms are:
# {'sorrow', 'sadden'}
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
text_data="hello i am gouse pasha and  welcome to SRU"

wordcloud = WordCloud(
    width=800,
    height=400,
    background_color='white'
).generate(text_data)


plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()
